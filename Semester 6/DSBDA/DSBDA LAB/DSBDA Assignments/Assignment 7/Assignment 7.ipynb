# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')

# %%
data
# Out:
#        age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52.0    1   0       125  212.0    0        1    168.0      0      1.0
# 1     53.0    1   0       140  203.0    1        0    155.0      1      3.1
# 2     70.0    1   0       145  174.0    0        1    125.0      1      2.6
# 3     61.0    1   0       148    NaN    0        1      NaN      0      0.0
# 4     62.0    0   0       138  294.0    1        1    106.0      0      1.9
# ...    ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 1020  59.0    1   1       140  221.0    0        1    164.0      1      0.0
# 1021  60.0    1   0       125  258.0    0        0    141.0      1      2.8
# 1022  47.0    1   0       110  275.0    0        0    118.0      1      1.0
# 1023  50.0    0   0       110  254.0    0        0    159.0      0      0.0
# 1024  54.0    1   0       120  188.0    0        1    113.0      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.isna().sum()
# Out:
# age         1
# sex         0
# cp          0
# trestbps    0
# chol        1
# fbs         0
# restecg     0
# thalach     1
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.fillna(data.mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Bar Plot

# %%
#Bar plots help visualize the distribution of categorical variables.
#Bar Plot - Count of 'sex' values
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=data, palette='pastel')
plt.xlabel('Sex (0: Female, 1: Male)')
plt.ylabel('Count')
plt.title('Bar Plot - Count of Sex Values')

# Adding a legend
plt.legend(labels=['Female', 'Male'])

plt.show()

# %% [markdown]
# # Histogram

# %%
#Histograms display the distribution of a single variable.
#Histogram - Distribution of 'thalach
plt.figure(figsize=(8,6))
plt.hist(data['thalach'], bins=20, color='skyblue',edgecolor='black')
plt.xlabel('Maximum heart rate')
plt.ylabel('Frequency')
plt.title('Histogram - Distribution of Thalach')
plt.show()

# %%
#Histogram - Distribution of 'chol'
plt.figure(figsize=(8,6))
plt.hist(data['chol'], bins=20, color='red',edgecolor='black')
plt.xlabel('Cholestrol')
plt.ylabel('Frequency')
plt.title('Histogram - Distribution of Cholestrol')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
#Visualizing the relationship between two numerical variables.
colors = {0: 'blue', 1: 'orange'}

plt.figure(figsize=(8, 6))
scatter = plt.scatter(data['trestbps'], data['chol'], c=data['sex'].map(colors))

plt.xlabel('Resting blood pressure')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot - Cholesterol vs Resting Blood Pressure')

# Creating a legend
legend_labels = ['Female', 'Male']
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[i], markersize=10) for i in colors.keys()]
plt.legend(legend_handles, legend_labels)

plt.show()

# %%
df = pd.read_csv('dataset_Facebook.csv', sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Bar Plot

# %%
#Visualize the distribution of posts across different months, weekdays, and hours. 

# for 'Post Month'
plt.figure(figsize=(10, 6))
sns.countplot(x='Post Month', data=df, palette='viridis')
plt.xlabel('Post Month')
plt.ylabel('Posts')
plt.title('Number of Posts by Month')
plt.show()

# %%
# for 'Post Weekday'
plt.figure(figsize=(10, 6))
sns.countplot(x='Post Weekday', data=df, palette='viridis')
plt.xlabel('Post Weekday')
plt.ylabel('Posts')
plt.title('Number of Posts by Weekday')
plt.show()

# %%
# for 'Post Hour'
plt.figure(figsize=(10, 6))
sns.countplot(x='Post Hour', data=df, palette='viridis')
plt.xlabel('Post Hour')
plt.ylabel('Posts')
plt.title('Number of Posts by Hour')
plt.show()

# %% [markdown]
# # Histogram

# %%
#Understand the distribution of each post
# for 'Lifetime Post Total Reach'
plt.figure(figsize=(10, 6))
plt.hist(df['Lifetime Post Total Reach'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Lifetime Post Total Reach')
plt.ylabel('Frequency')
plt.title('Distribution of Lifetime Post Total Reach')
plt.show()
